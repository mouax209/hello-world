# %%
import pandas as pd
import numpy as np 
df = pd.read_csv('house_sales.csv')
print(df)
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000   221900         3       1.00         1180
# 1      6414100192  20141209T000000   538000         3       2.25         2570
# 2      5631500400  20150225T000000   180000         2       1.00          770
# 3      2487200875  20141209T000000   604000         4       3.00         1960
# 4      1954400510  20150218T000000   510000         3       2.00         1680
# 5      7237550310  20140512T000000  1225000         4       4.50         5420
# 6      1321400060  20140627T000000   257500         3       2.25         1715
# 7      2008000270  20150115T000000   291850         3       1.50         1060
# 8      2414600126  20150415T000000   229500         3       1.00         1780
# 9      3793500160  20150312T000000   323000         3       2.50         1890
# 10     1736800520  20150403T000000   662500         3       2.50         3560
# ...

# %%
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
np.mean(df['price'])
# Out:
# 540088.1419053348

# %%
np.mean(df['bedrooms'])
# Out:
# 3.37084162309721

# %%
np.mean(df['bathrooms'])
# Out:
# 2.1147573219821405

# %%
np.mean(df['sqft_living'])
# Out:
# 2079.8997362698374

# %%
np.mean(df['yr_built'])
# Out:
# 1971.0051357978994

# %%
import statistics
statistics.mode(df['zipcode'])
# Out:
# 98103

# %%
import matplotlib.pyplot as plt
plt.scatter(x=df['yr_built'], y=df['price'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(x=df['yr_built'], y=df['price'])
plt.ylabel('Price (in thousands)')
plt.title('Seattle Housing Prices over the last 120 years')
plt.xlabel('Year')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df['yr_built'], bins=200, color='red')
plt.ylabel('Count')
plt.title('Home Built Counts by Year')
plt.xlabel('Year')
plt.show()

# %%
import numpy as np 
import pandas as pd 
# %matplotlib inline

# %%
import numpy as np 
import pandas as pd 

df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.zipcode.value_counts().head
# Out:
# <bound method NDFrame.head of 98103    602
# 98038    590
# 98115    583
# 98052    574
# 98117    553
# 98042    548
# 98034    545
# 98118    508
# 98023    499
# 98006    498
# 98133    494
# 98059    468
# 98058    455
# 98155    446
# 98074    441
# 98033    432
# 98027    412
# 98125    410
# 98056    406
# 98053    405
# 98001    362
# 98075    359
# 98126    354
# 98092    351
# 98144    343
# 98106    335
# 98116    330
# 98029    321
# 98004    317
# 98199    317
#         ...
# 98168    269
# 98112    269
# 98055    268
# 98107    266
# 98136    263
# 98178    262
# 98030    256
# 98177    255
# 98166    254
# 98022    234
# 98105    229
# 98045    221
# 98002    199
# 98077    198
# 98011    195
# 98019    190
# 98108    186
# 98119    184
# 98005    168
# 98007    141
# 98188    136
# 98032    125
# 98014    124
# 98070    118
# 98109    109
# 98102    105
# 98010    100
# 98024     81
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64>

# %%
df = pd.read_csv('house_sales.csv')
print(df)
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000   221900         3       1.00         1180
# 1      6414100192  20141209T000000   538000         3       2.25         2570
# 2      5631500400  20150225T000000   180000         2       1.00          770
# 3      2487200875  20141209T000000   604000         4       3.00         1960
# 4      1954400510  20150218T000000   510000         3       2.00         1680
# 5      7237550310  20140512T000000  1225000         4       4.50         5420
# 6      1321400060  20140627T000000   257500         3       2.25         1715
# 7      2008000270  20150115T000000   291850         3       1.50         1060
# 8      2414600126  20150415T000000   229500         3       1.00         1780
# 9      3793500160  20150312T000000   323000         3       2.50         1890
# 10     1736800520  20150403T000000   662500         3       2.50         3560
# ...

# %%
import numpy as np
np.median(df['price'])
# Out:
# 450000.0

# %%
np.median(df['price'])
# Out:
# 450000.0

# %%
np.median(df['bedrooms'])
# Out:
# 3.0

# %%
np.median(df['bathrooms'])
# Out:
# 2.25

# %%
np.median(df['sqft_living'])
# Out:
# 1910.0

# %%
np.median(df['yr_built'])
# Out:
# 1975.0

# %%
np.median(df['zipcode'])
# Out:
# 98065.0

# %%
import statistics

# %%
import numpy as np
(values, counts) = np.unique(df['price'], return_counts=True)

# The location in the values list of the most-frequently-occurring element.
ind = np.argmax(counts)

# The most frequent element.
values[ind]
# Out:
# 350000

# %%
(values, counts) = np.unique(df['bedrooms'], return_counts=True)

# The location in the values list of the most-frequently-occurring element.
ind = np.argmax(counts)

# The most frequent element.
values[ind]
# Out:
# 3

# %%
(values, counts) = np.unique(df['bathrooms'], return_counts=True)

# The location in the values list of the most-frequently-occurring element.
ind = np.argmax(counts)

# The most frequent element.
values[ind]
# Out:
# 2.5

# %%
(values, counts) = np.unique(df['sqft_living'], return_counts=True)

# The location in the values list of the most-frequently-occurring element.
ind = np.argmax(counts)

# The most frequent element.
values[ind]
# Out:
# 1300

# %%
(values, counts) = np.unique(df['yr_built'], return_counts=True)

# The location in the values list of the most-frequently-occurring element.
ind = np.argmax(counts)

# The most frequent element.
values[ind]
# Out:
# 2014

# %%
plt.hist(df['price'], bins=np.arange(75000, 7700000), alpha = .10)
plt.show()

# %%
np.min(df['price'])
# Out:
# 75000

# %%
np.max(df['price'])
# Out:
# 7700000

# %%
np.max(df['sqft_living'])
# Out:
# 13540

# %%
np.min(df['sqft_living'])
# Out:
# 290

# %%
df.groupby(['condition', 'price']).count()
# Out:
#                    id  date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# condition price
# 1         78000     1     1         1          1            1         1
#           81000     1     1         1          1            1         1
#           105500    1     1         1          1            1         1
#           125000    2     2         2          2            2         2
#           130000    1     1         1          1            1         1
#           142000    1     1         1          1            1         1
#           150000    1     1         1          1            1         1
#           190000    1     1         1          1            1         1
#           196000    1     1         1          1            1         1
#           210000    1     1         1          1            1         1
#           227000    1     1         1          1            1         1
#           235000    1     1         1          1            1         1
# ...

# %%
df.zipcode.value_counts()
# Out:
# 98103    602
# 98038    590
# 98115    583
# 98052    574
# 98117    553
# 98042    548
# 98034    545
# 98118    508
# 98023    499
# 98006    498
# 98133    494
# 98059    468
# 98058    455
# 98155    446
# 98074    441
# 98033    432
# 98027    412
# 98125    410
# 98056    406
# 98053    405
# 98001    362
# 98075    359
# 98126    354
# 98092    351
# 98144    343
# 98106    335
# 98116    330
# 98029    321
# 98004    317
# 98199    317
#         ...
# 98168    269
# 98112    269
# 98055    268
# 98107    266
# 98136    263
# 98178    262
# 98030    256
# 98177    255
# 98166    254
# 98022    234
# 98105    229
# 98045    221
# 98002    199
# 98077    198
# 98011    195
# 98019    190
# 98108    186
# 98119    184
# 98005    168
# 98007    141
# 98188    136
# 98032    125
# 98014    124
# 98070    118
# 98109    109
# 98102    105
# 98010    100
# 98024     81
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
df.plot.bar(zipcode)

# %%
df.groupby(['price', 'floors']).count()
# Out:
#                 id  date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# price   floors
# 75000   1.0      1     1         1          1            1         1
# 78000   1.0      1     1         1          1            1         1
# 80000   1.0      1     1         1          1            1         1
# 81000   1.0      1     1         1          1            1         1
# 82000   1.0      1     1         1          1            1         1
# 82500   1.0      1     1         1          1            1         1
# 83000   1.0      1     1         1          1            1         1
# 84000   1.0      1     1         1          1            1         1
# 85000   1.0      2     2         2          2            2         2
# 86500   1.0      1     1         1          1            1         1
# 89000   1.0      1     1         1          1            1         1
# 89950   1.0      1     1         1          1            1         1
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot(df['price'])
plt.show()

# %%
df.groupby(['sqft_above','price']).count()
# Out:
#                     id  date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# sqft_above price
# 290        142000    1     1         1          1            1         1
# 370        276000    1     1         1          1            1         1
# 380        245000    1     1         1          1            1         1
# 384        265000    1     1         1          1            1         1
# 390        228000    1     1         1          1            1         1
#            245000    1     1         1          1            1         1
# 410        325000    1     1         1          1            1         1
# 420        229050    1     1         1          1            1         1
#            280000    1     1         1          1            1         1
# 430        80000     1     1         1          1            1         1
# 440        290000    1     1         1          1            1         1
# 460        247000    1     1         1          1            1         1
# ...

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
plt.scatter(x=df['sqft_above'], y=df['price'], color='pink')
plt.title('Square Feet Above by Price')
plt.ylabel('Price')
plt.xlabel('Sqft Above')
plt.show()

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(df['condition'], color='purple')
plt.ylabel('price')
plt.title('Random Series')

plt.subplot(1, 2, 2)
plt.scatter(x = df['condition'], y = df['price'], color='green')
plt.ylabel('Squared Values')
plt.title('Squared Series')

plt.tight_layout()
plt.show()

# %%
df.groupby(['price', 'price']).count()
# Out:
#                  id  date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# price   price
# 75000   75000     1     1         1          1            1         1       1
# 78000   78000     1     1         1          1            1         1       1
# 80000   80000     1     1         1          1            1         1       1
# 81000   81000     1     1         1          1            1         1       1
# 82000   82000     1     1         1          1            1         1       1
# 82500   82500     1     1         1          1            1         1       1
# 83000   83000     1     1         1          1            1         1       1
# 84000   84000     1     1         1          1            1         1       1
# 85000   85000     2     2         2          2            2         2       2
# 86500   86500     1     1         1          1            1         1       1
# 89000   89000     1     1         1          1            1         1       1
# ...

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
plt.boxplot(df['price'])
plt.show()

# %%
plt.boxplot(df['bedrooms'])
plt.title('Number of Bedrooms')
plt.show()

# %%
plt.boxplot(df['bathrooms'])
plt.title('Bathrooms')
plt.show()

# %%
plt.boxplot(df['sqft_living'])
plt.show()

# %%
plt.boxplot(df['yr_built'])
plt.show()

# %%
plt.boxplot(df['zipcode'])
plt.show()

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
plt.hist(df['zipcode'])
plt.show()

# %%
plt.hist(df['zipcode'])
plt.show()
